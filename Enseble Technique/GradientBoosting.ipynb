# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import GradientBoostingClassifier

# %%
X_train = pd.read_csv('X_train.csv', index_col=0)
y_train = pd.read_csv('y_train.csv', index_col=0)
X_test = pd.read_csv('X_test.csv', index_col=0)
y_test = pd.read_csv('y_test.csv', index_col=0)

# %%
gbc = GradientBoostingClassifier(n_estimators=150, max_depth=2, loss = 'log_loss')

# %%
# y_test = y_test.drop('Unnamed: 0', axis=1)

# %%
X_train 
# X_train['Unnamed: 0']
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      34        0.249097        669    0.138398                 1          3
# 1      35        0.149569       1224    0.206278                 7          4
# 2      46        0.149569       1277    0.206278                 2          3
# 3      35        0.149569        660    0.206278                 7          1
# 4      26        0.249097        342    0.138398                 2          3
# ...   ...             ...        ...         ...               ...        ...
# 1971   28        0.249097        296    0.138398                 3          2
# 1972   30        0.196500       1030    0.170405                 2          3
# 1973   32        0.149569        950    0.138398                 8          3
# 1974   40        0.233248        277    0.149207                 3          2
# 1975   53        0.169843        647    0.192451                 7          1
#
#       EducationField  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  \
# 0           0.135776              1            1184                        4
# 1           0.146865              1            1962                        3
# 2           0.146865              1            1732                        3
# 3           0.146865              1            1492                        4
# 4           0.146865              1            1053                        1
# ...              ...            ...             ...                      ...
# 1971        0.146865              1            1440                        1
# 1972        0.197364              1             784                        4
# 1973        0.198775              1             637                        3
# 1974        0.145099              1             966                        1
# 1975        0.138035              1             959                        2
#
#       ...  RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0     ...                         3             80                 0
# 1     ...                         4             80                 0
# 2     ...                         2             80                 1
# 3     ...                         1             80                 1
# 4     ...                         2             80                 1
# ...   ...                       ...            ...               ...
# 1971  ...                         1             80                 0
# 1972  ...                         2             80                 0
# 1973  ...                         3             80                 0
# 1974  ...                         4             80                 2
# 1975  ...                         2             80                 0
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                    14                      3                3
# 1                    10                      2                3
# 2                    13                      5                2
# 3                     1                      3                3
# 4                     6                      2                3
# ...                 ...                    ...              ...
# 1971                  6                      2                3
# 1972                  5                      3                3
# 1973                 12                      3                3
# 1974                 19                      3                3
# 1975                 13                      2                2
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0                 13                   9                        4
# 1                 10                   8                        0
# 2                 10                   6                        0
# 3                  1                   0                        0
# 4                  3                   2                        1
# ...              ...                 ...                      ...
# 1971               3                   1                        0
# 1972               4                   2                        0
# 1973              10                   7                        6
# 1974              16                   7                        9
# 1975               7                   6                        5
#
#       YearsWithCurrManager
# 0                        9
# 1                        9
# 2                        3
# 3                        0
# 4                        2
# ...                    ...
# 1971                     2
# 1972                     3
# 1973                     8
# 1974                     5
# 1975                     3
#
# [1976 rows x 34 columns]

# %%
y_train
# y_train['Unnamed: 0']
# Out:
#       Attrition
# 0             0
# 1             0
# 2             0
# 3             0
# 4             1
# ...         ...
# 1971          1
# 1972          1
# 1973          1
# 1974          1
# 1975          1
#
# [1976 rows x 1 columns]

# %%
gbc.fit(X_train, y_train)
# Out:
# c:\Python311\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GradientBoostingClassifier(max_depth=2, n_estimators=150)

# %%
gbc.score(X_train, y_train)
# Out:
# 0.9428137651821862

# %%
gbc.fit(X_test, y_test)
# Out:
# c:\Python311\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GradientBoostingClassifier(max_depth=2, n_estimators=150)

# %%
gbc.score(X_test, y_test)
# Out:
# 0.9829931972789115
